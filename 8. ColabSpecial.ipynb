# %%
#install tensorflow
# !pip install tensorflow
# Out:
# ...
#   Using cached numpy-2.1.3-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
# Using cached numpy-2.1.3-cp312-cp312-win_amd64.whl (12.6 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.4
#     Uninstalling numpy-2.2.4:
#       Successfully uninstalled numpy-2.2.4
# ...
#   WARNING: Failed to remove contents in a temporary directory 'E:\GitHub\ML Practiacal\.venv\Lib\site-packages\~-mpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'E:\GitHub\ML Practiacal\.venv\Lib\site-packages\~-mpy'.
#   You can safely remove it manually.

# %%
# Ensure compatibility between TensorFlow and NumPy
# %pip install --upgrade numpy

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ...
#   Using cached numpy-2.2.4-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Using cached numpy-2.2.4-cp312-cp312-win_amd64.whl (12.6 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.3
#     Uninstalling numpy-2.1.3:
#       Successfully uninstalled numpy-2.1.3
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.2.4 which is incompatible.

# %%
tf.random.set_seed(42)

# %%
x = np.array([
    [0,0],
    [0,1],
    [1,0],
    [1,1]
],dtype=float)

# %%
y = np.array([
    [0],
    [1],
    [1],
    [0]
    ],dtype=float)

# %%
#Define the model
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(2, activation='relu', input_shape=(2,)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
# Out:
# e:\GitHub\ML Practiacal\.venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss="mean_squared_error",
            optimizer=tf.keras.optimizers.SGD(learning_rate=0.1),
            metrics=['accuracy'])

# %%
history = model.fit(x, y, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - accuracy: 0.7500 - loss: 0.3007
# Epoch 2/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7500 - loss: 0.3003
# Epoch 3/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7500 - loss: 0.2999
# Epoch 4/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7500 - loss: 0.2995
# Epoch 5/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7500 - loss: 0.2990
# Epoch 6/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7500 - loss: 0.2986
# Epoch 7/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7500 - loss: 0.2981
# Epoch 8/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7500 - loss: 0.2977
# Epoch 9/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7500 - loss: 0.2973
# Epoch 10/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7500 - loss: 0.2968
# Epoch 11/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7500 - loss: 0.2965
# Epoch 12/1000
# ...

# %%
plt.figure(figsize=(8,4))
plt.subplot(1,2,1)
plt.plot(history.history['loss'])
plt.title('Loss')
plt.subplot(1,2,2)
plt.plot(history.history['accuracy'])
plt.title('Accuracy')
plt.show()

# %%
xx , yy = np.meshgrid(np.linspace(0,1,100),np.linspace(0,1,100))
grid = np.c_[xx.ravel(),yy.ravel()]
Z = model.predict(grid, verbose=0).reshape(xx.shape)

plt.figure(figsize=(8,6))
plt.contour(xx,yy,Z,levels=50, cmap = "RdBu", alpha=0.8)
plt.colorbar(label = "Prediction")
plt.scatter(x[:,0], x[:,1], c=y.flatten(), cmap="RdBu", edgecolors='k', s=100)
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("Decision Boundary XOR")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.subplot(1,2,1)
plt.plot(history.history['loss'])
plt.title('Loss')
plt.subplot(1,2,2)
plt.show()
