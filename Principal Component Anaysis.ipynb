# %%
# %pip install seaborn

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in e:\github\ml practiacal\.venv\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: pandas>=1.2 in e:\github\ml practiacal\.venv\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in e:\github\ml practiacal\.venv\lib\site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in e:\github\ml practiacal\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in e:\github\ml practiacal\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in e:\github\ml practiacal\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\github\ml practiacal\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in e:\github\ml practiacal\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in e:\github\ml practiacal\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\github\ml practiacal\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in e:\github\ml practiacal\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\github\ml practiacal\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in e:\github\ml practiacal\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in e:\github\ml practiacal\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.datasets import fetch_olivetti_faces

# %%
faces = fetch_olivetti_faces(shuffle=True, random_state=42)
# Out:
# downloading Olivetti faces from https://ndownloader.figshare.com/files/5976027 to C:\Users\banda\scikit_learn_data

# %%
X = faces.data # Images data with 64x64 pixels

# %%
n_sample, n_features = X.shape

# %%
n_sample
# Out:
# 400

# %%
n_features
# Out:
# 4096

# %%
image_shape = faces.images[0].shape
image_shape
# Out:
# (64, 64)

# %%
plt.figure(figsize=(10, 10))
for i in range(100):
    plt.subplot(10, 10, i + 1)
    plt.imshow(faces.images[i], cmap='gray')
    plt.axis('off')
plt.show()

# %%
n_components = 150 # the number of principal components to keep

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=n_components, whiten=True, random_state=42 )
X_pca = pca.fit_transform(X)

# %%
n_print = 12

print("Propotion of total variation explaine by the first 12 PCs")
for i in range(n_print):
    variance_explained = pca.explained_variance_ratio_[i]
    print(f"PC {i + 1}: {variance_explained*100:.1f}%")
# Out:
# Propotion of total variation explaine by the first 12 PCs
# PC 1: 23.8%
# PC 2: 14.0%
# PC 3: 8.0%
# PC 4: 5.0%
# PC 5: 3.6%
# PC 6: 3.2%
# PC 7: 2.4%
# PC 8: 2.0%
# PC 9: 2.0%
# PC 10: 1.7%
# PC 11: 1.6%
# PC 12: 1.4%

# %%
cumulative_variance = np.cumsum(pca.explained_variance_ratio_)
plt.figure(figsize=(8, 5))
plt.plot(np.arange(1, n_components + 1), cumulative_variance, marker='o', linestyle='--')
# mark lines
plt.vlines(x=12, ymin=0, ymax=cumulative_variance[11], linestyles='dashed')
plt.hlines(y=cumulative_variance[11], xmin=0, xmax=12, linestyles='dashed')
plt.title('Explained Variance by Number of PCs')
plt.ylabel('Cumulative Explained Variance')
plt.xlabel('Number of Principal Components')
plt.grid()
plt.show()

# %%
n_eigenfaces = 12
plt.figure(figsize=(12, 6))
for i in range(n_eigenfaces):
    plt.subplot(3, 4, i + 1)
    plt.imshow(pca.components_[i].reshape(image_shape), cmap='gray')
    plt.title(f"PC {i + 1}")
    plt.axis('off')
plt.show()
